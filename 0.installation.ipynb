# %% [markdown]
# # Installation of NEDAS and optional dependencies
#
# More detailed guide can be found at <https://nedas.readthedocs.io>
#
# ## Install NEDAS
#
# NEDAS is available from the PyPI platform. You can install with ```pip install NEDAS```
#
# You can also clone the <https://github.com/nansencenter/NEDAS.git> repository and manually install:

# %%
# %cd ~
# %rm -rf NEDAS
# !git clone https://github.com/nansencenter/NEDAS.git
# %cd NEDAS
# %pip install .
# Out:
# /home/onyxia
# Cloning into 'NEDAS'...
# remote: Enumerating objects: 9548, done.
# remote: Counting objects: 100% (766/766), done.
# remote: Compressing objects: 100% (358/358), done.
# remote: Total 9548 (delta 452), reused 483 (delta 402), pack-reused 8782 (from 1)
# Receiving objects: 100% (9548/9548), 7.56 MiB | 12.07 MiB/s, done.
# Resolving deltas: 100% (6607/6607), done.
# /home/onyxia/NEDAS
# Processing ./.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 80.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.7 MB/s  0:00:00
# ...
#   Created wheel for NEDAS: filename=nedas-1.2.1.dev3+ge778818f6-py3-none-any.whl size=3372093 sha256=687d2f0dda7d5ca9ba6e07c9f863029042df7fa12e3a7d4f8075ce486ba5a427
# ...

# %% [markdown]
# ## Optional dependencies
#
# - `numba` provides JIT compilation of python function to speed it up during runtime
# - `cmocean` provides better colormaps

# %%
# %pip install numba
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 43.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 100.9 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [numba]32m1/2 [numba]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cmocean
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
