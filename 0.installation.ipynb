# %% [markdown]
# # Installation of NEDAS and optional dependencies
#
# More detailed guide can be found at <https://nedas.readthedocs.io>
#
# ## Install NEDAS
#
# NEDAS is available from the PyPI platform. You can install with ```pip install NEDAS```
#
# You can also clone the <https://github.com/nansencenter/NEDAS.git> repository and manually install:

# %%
# %cd ~
# !git clone https://github.com/nansencenter/NEDAS.git
# %cd NEDAS
# %pip install .
# Out:
# /home/onyxia
# Cloning into 'NEDAS'...
# remote: Enumerating objects: 9541, done.
# remote: Counting objects: 100% (759/759), done.
# remote: Compressing objects: 100% (353/353), done.
# remote: Total 9541 (delta 448), reused 478 (delta 400), pack-reused 8782 (from 1)
# Receiving objects: 100% (9541/9541), 7.55 MiB | 23.37 MiB/s, done.
# Resolving deltas: 100% (6603/6603), done.
# /home/onyxia/NEDAS
# Processing ./.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (2.4.4)
# Requirement already satisfied: scipy in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (1.17.1)
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (3.10.8)
# Requirement already satisfied: pyproj in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (3.7.2)
# Requirement already satisfied: pyshp in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (3.0.3)
# Requirement already satisfied: netCDF4 in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (1.7.4)
# Requirement already satisfied: PyYAML in /opt/python/lib/python3.13/site-packages (from NEDAS==1.2.1.dev2+ge38624e37) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->NEDAS==1.2.1.dev2+ge38624e37) (1.17.0)
# Requirement already satisfied: cftime in /opt/python/lib/python3.13/site-packages (from netCDF4->NEDAS==1.2.1.dev2+ge38624e37) (1.6.5)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from netCDF4->NEDAS==1.2.1.dev2+ge38624e37) (2026.2.25)
# Building wheels for collected packages: NEDAS
#   Building wheel for NEDAS (pyproject.toml) ... done
#   Created wheel for NEDAS: filename=nedas-1.2.1.dev2+ge38624e37-py3-none-any.whl size=3372067 sha256=2f01ff82f2ad4d45f133bfb2dd42d4f5911fae9a1530071234fdb903b3f7fe99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u9rlberh/wheels/da/53/57/f37114508b3d433d92c40a16b2bcd2803615229adad34a4dcc
# Successfully built NEDAS
# Installing collected packages: NEDAS
#   Attempting uninstall: NEDAS
#     Found existing installation: NEDAS 1.2.0
#     Uninstalling NEDAS-1.2.0:
#       Successfully uninstalled NEDAS-1.2.0
# Successfully installed NEDAS-1.2.1.dev2+ge38624e37
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Optional dependencies
#
# - Numba provides JIT compilation of python function to speed it up during runtime

# %%
# %pip install numba
# Out:
# Requirement already satisfied: numba in /opt/python/lib/python3.13/site-packages (0.65.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /opt/python/lib/python3.13/site-packages (from numba) (0.47.0)
# Requirement already satisfied: numpy>=1.22 in /opt/python/lib/python3.13/site-packages (from numba) (2.4.4)
# Note: you may need to restart the kernel to use updated packages.
