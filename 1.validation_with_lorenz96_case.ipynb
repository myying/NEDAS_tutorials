# %% [markdown]
# # Validation of NEDAS using the Lorenz 1996 model case
#
# ## Install the NEDAS system and dependencies

# %%
# %pip install NEDAS numba
# Out:
# Collecting NEDAS
#   Downloading nedas-1.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba
#   Downloading numba-0.65.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy in /opt/python/lib/python3.13/site-packages (from NEDAS) (2.4.4)
# Requirement already satisfied: scipy in /opt/python/lib/python3.13/site-packages (from NEDAS) (1.17.1)
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (from NEDAS) (3.10.8)
# Requirement already satisfied: pyproj in /opt/python/lib/python3.13/site-packages (from NEDAS) (3.7.2)
# Collecting pyshp (from NEDAS)
#   Downloading pyshp-3.0.3-py3-none-any.whl.metadata (65 kB)
# Collecting netCDF4 (from NEDAS)
#   Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: PyYAML in /opt/python/lib/python3.13/site-packages (from NEDAS) (6.0.3)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba)
#   Downloading llvmlite-0.47.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib->NEDAS) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->NEDAS) (1.17.0)
# Collecting cftime (from netCDF4->NEDAS)
#   Downloading cftime-1.6.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from netCDF4->NEDAS) (2026.2.25)
# Downloading nedas-1.2.0-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 50.0 MB/s  0:00:00
# Downloading numba-0.65.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 93.3 MB/s  0:00:00
# Downloading llvmlite-0.47.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 84.7 MB/s  0:00:00m0:00:0100:01m
# Downloading netcdf4-1.7.4-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 104.8 MB/s  0:00:00
# Downloading cftime-1.6.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.2 MB/s  0:00:00
# Downloading pyshp-3.0.3-py3-none-any.whl (58 kB)
# Installing collected packages: pyshp, llvmlite, cftime, numba, netCDF4, NEDAS
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [NEDAS]32m5/6 [NEDAS]4]]
# Successfully installed NEDAS-1.2.0 cftime-1.6.5 llvmlite-0.47.0 netCDF4-1.7.4 numba-0.65.0 pyshp-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

from NEDAS.config import Config
from NEDAS import get_scheme

# %% [markdown]
# ## Initialization
#
# The config object holds all parameters defined in a yaml file, we can also make some changes

# %%
config = Config(config_file="lorenz96/config.yml", io_mode='online', call_stack_max_level=1, run_analysis=True, quiet=False)

# %%
obs_rec_id = 0
config.obs_def[obs_rec_id]
# Out:
# {'name': 'state',
#  'dataset_src': 'synthetic',
#  'model_src': 'lorenz96',
#  'nobs': 10,
#  'err': {'type': 'normal', 'std': 0.1},
#  'hroi': 5,
#  'vroi': inf,
#  'troi': inf,
#  'impact_on_state': None}

# %%
config.obs_def[obs_rec_id]['err']['std'] = 0.1

# %%
config.obs_def[obs_rec_id]['hroi'] = 5

# %%
obs_x = [i for i in range(0, 20, 2)]
config.dataset_def['synthetic']['obs_x'] = obs_x
config.obs_def[obs_rec_id]['nobs'] = len(obs_x)

# %% [markdown]
# ## Run the main scheme
#
# The main scheme is the top level manager of runtime execution, it can be initialized with the config object.
#
# Notes:
#
# - The first cycle takes a bit longer since the python functions are being compiled by numba.njit

# %%
scheme = get_scheme(config)
scheme()
# Out:
# █▄  █ █▀▀▀ █▀▀▄ ▄▀▀▄ ▄▀▀▀
# █ ▀▄█ █▀▀  █  █ █▀▀█ ▀▀▀█
# ▀   ▀ ▀▀▀▀ ▀▀▀  ▀  ▀ ▀▀▀  version 1.2.0
#
# INITIALIZING...
#
# CONFIGURATION SUMMARY
# =====================
# Directories:
#   Work Dir:      /home/onyxia/work/NEDAS_tutorials/lorenz96
#   NEDAS Root:    /opt/python/lib/python3.13/site-packages/NEDAS
#
# Time Configuration:
#   Current Time:  2001-01-01 00:00:00+00:00
#   Experiment:    [2001-01-01 00:00:00+00:00] to [2001-01-30 00:00:00+00:00]
#   Analysis:      [2001-01-01 00:00:00+00:00] to [2001-01-28 00:00:00+00:00]
#   Periods:       Cycle: 6h | Forecast: N/A
#
# Parallel Scheme:
#   Total Procs:   1
#   Decomposition: 1 (mem) x 1 (rec)
#   Procs for utility funcs: 1
#   Host:          local
#   Scheduler:     None | Project: None
#   Queue/Mode:    None | Parallel mode: serial
#
# Analysis Scheme:
#   General:       Scheme: filter | Ensemble Size: 20 | IO: online
#   Grid Type:     lorenz96
#   Iteration:     1 of 1 (Outer Loops)
#   Assimilator:   Type: ETKF
#   Updator:       Type: additive
#   Inflation:     prior,multiplicative (coef: 1.0, adaptive: False)
#   Localization:  H: gaspari_cohn | V: gaspari_cohn | T: exponential
#   Multiscale:    Resolution Levels: [0] | Character Lengths: [1]
#                  Localization Factor: [1] | Obs Err Factor: [1]
#
# Definitions:
#   Models Used:   lorenz96
#   Datasets:      synthetic
#   State Vector:  state (lorenz96)
#   Observations:  state (synthetic)
#
# Workflow Status:
#   Active Steps:  Preprocess -> Analysis -> Postprocess -> Forecast -> Diagnose
#   Debug Mode:    False | Timer: True | Interactive: True
#
#
# FilterAnalysisScheme:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │
# ◈ PREPARING...
# │
# ◈ CYCLING START...
# │
# ◈ CURRENT CYCLE: 2001-01-01 00:00:00+00:00 -> 2001-01-01 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-01 06:00:00+00:00 -> 2001-01-01 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-01 12:00:00+00:00 -> 2001-01-01 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-01 18:00:00+00:00 -> 2001-01-02 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-02 00:00:00+00:00 -> 2001-01-02 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-02 06:00:00+00:00 -> 2001-01-02 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-02 12:00:00+00:00 -> 2001-01-02 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-02 18:00:00+00:00 -> 2001-01-03 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-03 00:00:00+00:00 -> 2001-01-03 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-03 06:00:00+00:00 -> 2001-01-03 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-03 12:00:00+00:00 -> 2001-01-03 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-03 18:00:00+00:00 -> 2001-01-04 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-04 00:00:00+00:00 -> 2001-01-04 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-04 06:00:00+00:00 -> 2001-01-04 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-04 12:00:00+00:00 -> 2001-01-04 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-04 18:00:00+00:00 -> 2001-01-05 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-05 00:00:00+00:00 -> 2001-01-05 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-05 06:00:00+00:00 -> 2001-01-05 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-05 12:00:00+00:00 -> 2001-01-05 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-05 18:00:00+00:00 -> 2001-01-06 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-06 00:00:00+00:00 -> 2001-01-06 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-06 06:00:00+00:00 -> 2001-01-06 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-06 12:00:00+00:00 -> 2001-01-06 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-06 18:00:00+00:00 -> 2001-01-07 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-07 00:00:00+00:00 -> 2001-01-07 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-07 06:00:00+00:00 -> 2001-01-07 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-07 12:00:00+00:00 -> 2001-01-07 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-07 18:00:00+00:00 -> 2001-01-08 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-08 00:00:00+00:00 -> 2001-01-08 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-08 06:00:00+00:00 -> 2001-01-08 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-08 12:00:00+00:00 -> 2001-01-08 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-08 18:00:00+00:00 -> 2001-01-09 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-09 00:00:00+00:00 -> 2001-01-09 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-09 06:00:00+00:00 -> 2001-01-09 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-09 12:00:00+00:00 -> 2001-01-09 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-09 18:00:00+00:00 -> 2001-01-10 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-10 00:00:00+00:00 -> 2001-01-10 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-10 06:00:00+00:00 -> 2001-01-10 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-10 12:00:00+00:00 -> 2001-01-10 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-10 18:00:00+00:00 -> 2001-01-11 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-11 00:00:00+00:00 -> 2001-01-11 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-11 06:00:00+00:00 -> 2001-01-11 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-11 12:00:00+00:00 -> 2001-01-11 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-11 18:00:00+00:00 -> 2001-01-12 00:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-12 00:00:00+00:00 -> 2001-01-12 06:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-12 06:00:00+00:00 -> 2001-01-12 12:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01
00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-29 12:00:00+00:00 -> 2001-01-29 18:00:00+00:00
# │
# ◈ CURRENT CYCLE: 2001-01-29 18:00:00+00:00 -> 2001-01-30 00:00:00+00:00
# │
# 🏁  CYCLING COMPLETE.
# ✅    24.83s

# %% [markdown]
# ## Collect data from memory

# %%
model = scheme.c.models['lorenz96']
dataset = scheme.c.datasets['synthetic']

# %%
scheme.c.time = scheme.c.config.time_start

truth_state = []
while scheme.c.time < scheme.c.config.time_end:
    truth_state.append(model.read_var_from_memory(tag='truth', name='state', member=None, time=scheme.c.time))
    scheme.c.time = scheme.c.next_time

# %%
scheme.c.time = scheme.c.config.time_start

prior_state = []
post_state = []
while scheme.c.time < scheme.c.config.time_end:
    ens = []
    for m in range(scheme.c.nens):
        ens.append(model.read_var_from_memory(tag='prior', name='state', member=m, time=scheme.c.time))
    prior_state.append(ens)
    ens = []
    for m in range(scheme.c.nens):
        if scheme.c.time >= scheme.c.config.time_analysis_start and scheme.c.time <= scheme.c.config.time_analysis_end:
            ens.append(model.read_var_from_memory(tag='post', name='state', member=m, time=scheme.c.time))
        else:
            ens.append(np.full(scheme.c.grid.x.shape, np.nan))
    post_state.append(ens)
    scheme.c.time = scheme.c.next_time

# %%
nobs = scheme.c.obs.info.records[0].nobs
scheme.c.time = scheme.c.config.time_start

obs_val = []
obs_x = []
while scheme.c.time < scheme.c.config.time_end:
    if scheme.c.time >= scheme.c.config.time_analysis_start and scheme.c.time <= scheme.c.config.time_analysis_end:
        seq = dataset.read_obs_from_memory(tag='raw', name='state', member=None, time=scheme.c.time)
        obs_val.append(seq['obs'])
        obs_x.append(seq['x'])
    else:
        obs_val.append(np.full(nobs, np.nan))
        obs_x.append(np.full(nobs, np.nan))
    scheme.c.time = scheme.c.next_time

# %%
#plt.contourf(np.array(truth_state).T)
#m = 1
#plt.contourf((np.array(prior_state)[:, m, :] - np.array(truth_state)).T)

# %% [markdown]
# ## Plot results
#
# ### Animation of the state over time

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ensemble_lines = [ax.plot([], [], color='c', alpha=0.5)[0] for _ in range(scheme.c.nens)]
ensemble_mean = ax.plot([], [], color='b', linewidth=2)[0]
obs_plot = ax.plot([], [], 'x', color='r', markersize=10)[0]
truth_line = ax.plot([], [], color='k', linewidth=2)[0]

def init():
    """Set up the axis limits and background."""
    ax.set_xlim(scheme.c.grid.x.min(), scheme.c.grid.x.max())
    ax.set_ylim(-10, 15)
    return ensemble_lines + [ensemble_mean, obs_plot, truth_line]

def update(n):
    """Update the data for frame n."""
    # Update ensemble
    for m in range(scheme.c.nens):
        ensemble_lines[m].set_data(scheme.c.grid.x, post_state[n][m])
    ensemble_mean.set_data(scheme.c.grid.x, np.mean(np.array(post_state[n]), axis=0))

    # Update observations
    obs_plot.set_data(obs_x[n], obs_val[n])
    
    # Update truth
    truth_line.set_data(scheme.c.grid.x, truth_state[n])
    
    ax.set_title(f"Time Step: {n}")
    return ensemble_lines + [ensemble_mean, obs_plot, truth_line]

# 2. Create the animation
nt = len(truth_state)
ani = FuncAnimation(fig, update, frames=range(nt), init_func=init, blit=True, interval=50)
plt.close()

HTML(ani.to_jshtml())

# %% [markdown]
# ### Time series of error and spread

# %% [markdown]
# ## Some diagnostics

# %%
dist = scheme.c.grid.distance(scheme.c.grid.x, 1.3)
rho = scheme.c.localization_funcs['horizontal'](dist, 3)

# %%
plt.plot(rho)
